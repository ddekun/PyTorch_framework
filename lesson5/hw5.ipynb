# %% [markdown]
# <a href="https://colab.research.google.com/github/ddekun/PyTorch_framework/blob/lesson5/lesson5/hw5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Фреймворк PyTorch для разработки искусственных нейронных сетей

# %% [markdown]
# ### Урок 5. Сегментация изображений

# %% [markdown]
# Необходимо подготовить датасет https://www.kaggle.com/olekslu/makeup-lips-segmentation-28k-samples для обучения модели на сегментацию губ
# Обучить модель на выбор из segmentation_models_pytorch
# У кого нет возможности работать через каггл (нет верификации), то можете данные взять по ссылке: https://disk.yandex.ru/d/nWMoBVgvWYcI7g

# %%
# !pip install segmentation-models-pytorch
# Out:
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.3.3-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.15.2+cu118)
# Collecting pretrainedmodels==0.7.4 (from segmentation-models-pytorch)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting efficientnet-pytorch==0.7.1 (from segmentation-models-pytorch)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting timm==0.9.2 (from segmentation-models-pytorch)
#   Downloading timm-0.9.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 39.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (4.65.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (8.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.0.1+cu118)
# Collecting munch (from pretrainedmodels==0.7.4->segmentation-models-pytorch)
#   Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2->segmentation-models-pytorch) (6.0)
# Collecting huggingface-hub (from timm==0.9.2->segmentation-models-pytorch)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 33.0 MB/s eta 0:00:00
# Collecting safetensors (from timm==0.9.2->segmentation-models-pytorch)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (16.0.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.2->segmentation-models-pytorch) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.2->segmentation-models-pytorch) (23.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16427 sha256=60615d7945b843d4d247b4fb1d83e536c3c6ea1ac24fd2e61bc8746f5b9da05b
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60945 sha256=52103c7f5f2236d97a3fe4328192a20ec71af5f2cf8ee9661cdff009f87e9096
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: safetensors, munch, huggingface-hub, timm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.7.1 huggingface-hub-0.16.4 munch-4.0.0 pretrainedmodels-0.7.4 safetensors-0.3.1 segmentation-models-pytorch-0.3.3 timm-0.9.2

# %%
import os
import time

from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import cv2

import torch
from torch import nn, optim

import segmentation_models_pytorch as smp

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Geekbrains/PyTorch_framework/Lesson5/set-lipstick-original.zip -d lips_dataset/
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: lips_dataset/mask/mask00023595.png
#   inflating: lips_dataset/mask/mask00023596.png
#   inflating: lips_dataset/mask/mask00023597.png
#   inflating: lips_dataset/mask/mask00023598.png
#   inflating: lips_dataset/mask/mask00023599.png
#   inflating: lips_dataset/mask/mask00023600.png
#   inflating: lips_dataset/mask/mask00023601.png
#   inflating: lips_dataset/mask/mask00023602.png
#   inflating: lips_dataset/mask/mask00023603.png
#   inflating: lips_dataset/mask/mask00023604.png
#   inflating: lips_dataset/mask/mask00023605.png
#   inflating: lips_dataset/mask/mask00023606.png
#   inflating: lips_dataset/mask/mask00023607.png
#   inflating: lips_dataset/mask/mask00023608.png
#   inflating: lips_dataset/mask/mask00023609.png
#   inflating: lips_dataset/mask/mask00023610.png
#   inflating: lips_dataset/mask/mask00023611.png
#   inflating: lips_dataset/mask/mask00023612.png
#   inflating: lips_dataset/mask/mask00023613.png
#   inflating: lips_dataset/mask/mask00023614.png
#   inflating: lips_dataset/mask/mask00023615.png
#   inflating: lips_dataset/mask/mask00023616.png
#   inflating: lips_dataset/mask/mask00023617.png
#   inflating: lips_dataset/mask/mask00023618.png
#   inflating: lips_dataset/mask/mask00023619.png
#   inflating: lips_dataset/mask/mask00023620.png
#   inflating: lips_dataset/mask/mask00023621.png
#   inflating: lips_dataset/mask/mask00023622.png
#   inflating: lips_dataset/mask/mask00023623.png
#   inflating: lips_dataset/mask/mask00023624.png
#   inflating: lips_dataset/mask/mask00023625.png
#   inflating: lips_dataset/mask/mask00023626.png
#   inflating: lips_dataset/mask/mask00023627.png
#   inflating: lips_dataset/mask/mask00023628.png
#   inflating: lips_dataset/mask/mask00023629.png
#   inflating: lips_dataset/mask/mask00023630.png
#   inflating: lips_dataset/mask/mask00023631.png
#   inflating: lips_dataset/mask/mask00023632.png
#   inflating: lips_dataset/mask/mask00023633.png
#   inflating: lips_dataset/mask/mask00023634.png
#   inflating: lips_dataset/mask/mask00023635.png
#   inflating: lips_dataset/mask/mask00023636.png
#   inflating: lips_dataset/mask/mask00023637.png
#   inflating: lips_dataset/mask/mask00023638.png
#   inflating: lips_dataset/mask/mask00023639.png
#   inflating: lips_dataset/mask/mask00023640.png
#   inflating: lips_dataset/mask/mask00023641.png
#   inflating: lips_dataset/mask/mask00023642.png
#   inflating: lips_dataset/mask/mask00023643.png
#   inflating: lips_dataset/mask/mask00023644.png
#   inflating: lips_dataset/mask/mask00023645.png
#   inflating: lips_dataset/mask/mask00023646.png
#   inflating: lips_dataset/mask/mask00023647.png
#   inflating: lips_dataset/mask/mask00023648.png
#   inflating: lips_dataset/mask/mask00023649.png
#   inflating: lips_dataset/mask/mask00023650.png
#   inflating: lips_dataset/mask/mask00023651.png
#   inflating: lips_dataset/mask/mask00023652.png
#   inflating: lips_dataset/mask/mask00023653.png
#   inflating: lips_dataset/mask/mask00023654.png
#   inflating: lips_dataset/mask/mask00023655.png
#   inflating: lips_dataset/mask/mask00023656.png
#   inflating: lips_dataset/mask/mask00023657.png
#   inflating: lips_dataset/mask/mask00023658.png
#   inflating: lips_dataset/mask/mask00023659.png
#   inflating: lips_dataset/mask/mask00023660.png
#   inflating: lips_dataset/mask/mask00023661.png
#   inflating: lips_dataset/mask/mask00023662.png
#   inflating: lips_dataset/mask/mask00023663.png
#   inflating: lips_dataset/mask/mask00023664.png
#   inflating: lips_dataset/mask/mask00023665.png
#   inflating: lips_dataset/mask/mask00023666.png
#   inflating: lips_dataset/mask/mask00023667.png
#   inflating: lips_dataset/mask/mask00023668.png
#   inflating: lips_dataset/mask/mask00023669.png
#   inflating: lips_dataset/mask/mask00023670.png
#   inflating: lips_dataset/mask/mask00023671.png
#   inflating: lips_dataset/mask/mask00023672.png
#   inflating: lips_dataset/mask/mask00023673.png
#   inflating: lips_dataset/mask/mask00023674.png
#   inflating: lips_dataset/mask/mask00023675.png
#   inflating: lips_dataset/mask/mask00023676.png
#   inflating: lips_dataset/mask/mask00023677.png
#   inflating: lips_dataset/mask/mask00023678.png
#   inflating: lips_dataset/mask/mask00023679.png
#   inflating: lips_dataset/mask/mask00023680.png
#   inflating: lips_dataset/mask/mask00023681.png
#   inflating: lips_dataset/mask/mask00023682.png
#   inflating: lips_dataset/mask/mask00023683.png
#   inflating: lips_dataset/mask/mask00023684.png
#   inflating: lips_dataset/mask/mask00023685.png
#   inflating: lips_dataset/mask/mask00023686.png
#   inflating: lips_dataset/mask/mask00023687.png
#   inflating: lips_dataset/mask/mask00023688.png
#   inflating: lips_dataset/mask/mask00023689.png
#   inflating: lips_dataset/mask/mask00023690.png
#   inflating: lips_dataset/mask/mask00023691.png
#   inflating: lips_dataset/mask/mask00023692.png
#   inflating: lips_dataset/mask/mask00023693.png
#   inflating: lips_dataset/mask/mask00023694.png
#   inflating: lips_dataset/mask/mask00023695.png
#   inflating: lips_dataset/mask/mask00023696.png
#   inflating: lips_dataset/mask/mask00023697.png
#   inflating: lips_dataset/mask/mask00023698.png
#   inflating: lips_dataset/mask/mask00023699.png
#   inflating: lips_dataset/mask/mask00023700.png
#   inflating: lips_dataset/mask/mask00023701.png
#   inflating: lips_dataset/mask/mask00023702.png
#   inflating: lips_dataset/mask/mask00023703.png
#   inflating: lips_dataset/mask/mask00023704.png
#   inflating: lips_dataset/mask/mask00023705.png
#   inflating: lips_dataset/mask/mask00023706.png
#   inflating: lips_dataset/mask/mask00023707.png
#   inflating: lips_dataset/mask/mask00023708.png
#   inflating: lips_dataset/mask/mask00023709.png
#   inflating: lips_dataset/mask/mask00023710.png
#   inflating: lips_dataset/mask/mask00023711.png
#   inflating: lips_dataset/mask/mask00023712.png
#   inflating: lips_dataset/mask/mask00023713.png
#   inflating: lips_dataset/mask/mask00023714.png
#   inflating: lips_dataset/mask/mask00023715.png
#   inflating: lips_dataset/mask/mask00023716.png
#   inflating: lips_dataset/mask/mask00023717.png
#   inflating: lips_dataset/mask/mask00023718.png
#   inflating: lips_dataset/mask/mask00023719.png
#   inflating: lips_dataset/mask/mask00023720.png
#   inflating: lips_dataset/mask/mask00023721.png
#   inflating: lips_dataset/mask/mask00023722.png
#   inflating: lips_dataset/mask/mask00023723.png
#   inflating: lips_dataset/mask/mask00023724.png
#   inflating: lips_dataset/mask/mask00023725.png
#   inflating: lips_dataset/mask/mask00023726.png
#   inflating: lips_dataset/mask/mask00023727.png
#   inflating: lips_dataset/mask/mask00023728.png
#   inflating: lips_dataset/mask/mask00023729.png
#   inflating: lips_dataset/mask/mask00023730.png
#   inflating: lips_dataset/mask/mask00023731.png
#   inflating: lips_dataset/mask/mask00023732.png
#   inflating: lips_dataset/mask/mask00023733.png
#   inflating: lips_dataset/mask/mask00023734.png
#   inflating: lips_dataset/mask/mask00023735.png
#   inflating: lips_dataset/mask/mask00023736.png
#   inflating: lips_dataset/mask/mask00023737.png
#   inflating: lips_dataset/mask/mask00023738.png
#   inflating: lips_dataset/mask/mask00023739.png
#   inflating: lips_dataset/mask/mask00023740.png
#   inflating: lips_dataset/mask/mask00023741.png
#   inflating: lips_dataset/mask/mask00023742.png
#   inflating: lips_dataset/mask/mask00023743.png
#   inflating: lips_dataset/mask/mask00023744.png
#   inflating: lips_dataset/mask/mask00023745.png
#   inflating: lips_dataset/mask/mask00023746.png
#   inflating: lips_dataset/mask/mask00023747.png
#   inflating: lips_dataset/mask/mask00023748.png
#   inflating: lips_dataset/mask/mask00023749.png
#   inflating: lips_dataset/mask/mask00023750.png
#   inflating: lips_dataset/mask/mask00023751.png
#   inflating: lips_dataset/mask/mask00023752.png
#   inflating: lips_dataset/mask/mask00023753.png
#   inflating: lips_dataset/mask/mask00023754.png
#   inflating: lips_dataset/mask/mask00023755.png
#   inflating: lips_dataset/mask/mask00023756.png
#   inflating: lips_dataset/mask/mask00023757.png
#   inflating: lips_dataset/mask/mask00023758.png
#   inflating: lips_dataset/mask/mask00023759.png
#   inflating: lips_dataset/mask/mask00023760.png
#   inflating: lips_dataset/mask/mask00023761.png
#   inflating: lips_dataset/mask/mask00023762.png
#   inflating: lips_dataset/mask/mask00023763.png
#   inflating: lips_dataset/mask/mask00023764.png
#   inflating: lips_dataset/mask/mask00023765.png
#   inflating: lips_dataset/mask/mask00023766.png
#   inflating: lips_dataset/mask/mask00023767.png
#   inflating: lips_dataset/mask/mask00023768.png
#   inflating: lips_dataset/mask/mask00023769.png
#   inflating: lips_dataset/mask/mask00023770.png
#   inflating: lips_dataset/mask/mask00023771.png
#   inflating: lips_dataset/mask/mask00023772.png
#   inflating: lips_dataset/mask/mask00023773.png
#   inflating: lips_dataset/mask/mask00023774.png
#   inflating: lips_dataset/mask/mask00023775.png
#   inflating: lips_dataset/mask/mask00023776.png
#   inflating: lips_dataset/mask/mask00023777.png
#   inflating: lips_dataset/mask/mask00023778.png
#   inflating: lips_dataset/mask/mask00023779.png
#   inflating: lips_dataset/mask/mask00023780.png
#   inflating: lips_dataset/mask/mask00023781.png
#   inflating: lips_dataset/mask/mask00023782.png
#   inflating: lips_dataset/mask/mask00023783.png
#   inflating: lips_dataset/mask/mask00023784.png
#   inflating: lips_dataset/mask/mask00023785.png
#   inflating: lips_dataset/mask/mask00023786.png
#   inflating: lips_dataset/mask/mask00023787.png
#   inflating: lips_dataset/mask/mask00023788.png
#   inflating: lips_dataset/mask/mask00023789.png
#   inflating: lips_dataset/mask/mask00023790.png
#   inflating: lips_dataset/mask/mask00023791.png
#   inflating: lips_dataset/mask/mask00023792.png
#   inflating: lips_dataset/mask/mask00023793.png
#   inflating: lips_dataset/mask/mask00023794.png
#   inflating: lips_dataset/mask/mask00023795.png
#   inflating: lips_dataset/mask/mask00023796.png
#   inflating: lips_dataset/mask/mask00023797.png
#   inflating: lips_dataset/mask/mask00023798.png
#   inflating: lips_dataset/mask/mask00023799.png
#   inflating: lips_dataset/mask/mask00023800.png
#   inflating: lips_dataset/mask/mask00023801.png
#   inflating: lips_dataset/mask/mask00023802.png
#   inflating: lips_dataset/mask/mask00023803.png
#   inflating: lips_dataset/mask/mask00023804.png
#   inflating: lips_dataset/mask/mask00023805.png
#   inflating: lips_dataset/mask/mask00023806.png
#   inflating: lips_dataset/mask/mask00023807.png
#   inflating: lips_dataset/mask/mask00023808.png
#   inflating: lips_dataset/mask/mask00023809.png
#   inflating: lips_dataset/mask/mask00023810.png
#   inflating: lips_dataset/mask/mask00023811.png
#   inflating: lips_dataset/mask/mask00023812.png
#   inflating: lips_dataset/mask/mask00023813.png
#   inflating: lips_dataset/mask/mask00023814.png
#   inflating: lips_dataset/mask/mask00023815.png
#   inflating: lips_dataset/mask/mask00023816.png
#   inflating: lips_dataset/mask/mask00023817.png
#   inflating: lips_dataset/mask/mask00023818.png
#   inflating: lips_dataset/mask/mask00023819.png
#   inflating: lips_dataset/mask/mask00023820.png
#   inflating: lips_dataset/mask/mask00023821.png
#   inflating: lips_dataset/mask/mask00023822.png
#   inflating: lips_dataset/mask/mask00023823.png
#   inflating: lips_dataset/mask/mask00023824.png
#   inflating: lips_dataset/mask/mask00023825.png
#   inflating: lips_dataset/mask/mask00023826.png
#   inflating: lips_dataset/mask/mask00023827.png
#   inflating: lips_dataset/mask/mask00023828.png
#   inflating: lips_dataset/mask/mask00023829.png
#   inflating: lips_dataset/mask/mask00023830.png
#   inflating: lips_dataset/mask/mask00023831.png
#   inflating: lips_dataset/mask/mask00023832.png
#   inflating: lips_dataset/mask/mask00023833.png
#   inflating: lips_dataset/mask/mask00023834.png
#   inflating: lips_dataset/mask/mask00023835.png
#   inflating: lips_dataset/mask/mask00023836.png
#   inflating: lips_dataset/mask/mask00023837.png
#   inflating: lips_dataset/mask/mask00023838.png
#   inflating: lips_dataset/mask/mask00023839.png
#   inflating: lips_dataset/mask/mask00023840.png
#   inflating: lips_dataset/mask/mask00023841.png
#   inflating: lips_dataset/mask/mask00023842.png
#   inflating: lips_dataset/mask/mask00023843.png
#   inflating: lips_dataset/mask/mask00023844.png
#   inflating: lips_dataset/mask/mask00023845.png
#   inflating: lips_dataset/mask/mask00023846.png
#   inflating: lips_dataset/mask/mask00023847.png
#   inflating: lips_dataset/mask/mask00023848.png
#   inflating: lips_dataset/mask/mask00023849.png
#   inflating: lips_dataset/mask/mask00023850.png
#   inflating: lips_dataset/mask/mask00023851.png
#   inflating: lips_dataset/mask/mask00023852.png
#   inflating: lips_dataset/mask/mask00023853.png
#   inflating: lips_dataset/mask/mask00023854.png
#   inflating: lips_dataset/mask/mask00023855.png
#   inflating: lips_dataset/mask/mask00023856.png
#   inflating: lips_dataset/mask/mask00023857.png
#   inflating: lips_dataset/mask/mask00023858.png
#   inflating: lips_dataset/mask/mask00023859.png
#   inflating: lips_dataset/mask/mask00023860.png
#   inflating: lips_dataset/mask/mask00023861.png
#   inflating: lips_dataset/mask/mask00023862.png
#   inflating: lips_dataset/mask/mask00023863.png
#   inflating: lips_dataset/mask/mask00023864.png
#   inflating: lips_dataset/mask/mask00023865.png
#   inflating: lips_dataset/mask/mask00023866.png
#   inflating: lips_dataset/mask/mask00023867.png
#   inflating: lips_dataset/mask/mask00023868.png
#   inflating: lips_dataset/mask/mask00023869.png
#   inflating: lips_dataset/mask/mask00023870.png
#   inflating: lips_dataset/mask/mask00023871.png
#   inflating: lips_dataset/mask/mask00023872.png
#   inflating: lips_dataset/mask/mask00023873.png
#   inflating: lips_dataset/mask/mask00023874.png
#   inflating: lips_dataset/mask/mask00023875.png
#   inflating: lips_dataset/mask/mask00023876.png
#   inflating: lips_dataset/mask/mask00023877.png
#   inflating: lips_dataset/mask/mask00023878.png
#   inflating: lips_dataset/mask/mask00023879.png
#   inflating: lips_dataset/mask/mask00023880.png
#   inflating: lips_dataset/mask/mask00023881.png
#   inflating: lips_dataset/mask/mask00023882.png
#   inflating: lips_dataset/mask/mask00023883.png
#   inflating: lips_dataset/mask/mask00023884.png
#   inflating: lips_dataset/mask/mask00023885.png
#   inflating: lips_dataset/mask/mask00023886.png
#   inflating: lips_dataset/mask/mask00023887.png
#   inflating: lips_dataset/mask/mask00023888.png
#   inflating: lips_dataset/mask/mask00023889.png
#   inflating: lips_dataset/mask/mask00023890.png
#   inflating: lips_dataset/mask/mask00023891.png
#   inflating: lips_dataset/mask/mask00023892.png
#   inflating: lips_dataset/mask/mask00023893.png
#   inflating: lips_dataset/mask/mask00023894.png
#   inflating: lips_dataset/mask/mask00023895.png
#   inflating: lips_dataset/mask/mask00023896.png
#   inflating: lips_dataset/mask/mask00023897.png
#   inflating: lips_dataset/mask/mask00023898.png
#   inflating: lips_dataset/mask/mask00023899.png
#   inflating: lips_dataset/mask/mask00023900.png
#   inflating: lips_dataset/mask/mask00023901.png
#   inflating: lips_dataset/mask/mask00023902.png
#   inflating: lips_dataset/mask/mask00023903.png
#   inflating: lips_dataset/mask/mask00023904.png
#   inflating: lips_dataset/mask/mask00023905.png
#   inflating: lips_dataset/mask/mask00023906.png
#   inflating: lips_dataset/mask/mask00023907.png
#   inflating: lips_dataset/mask/mask00023908.png
#   inflating: lips_dataset/mask/mask00023909.png
#   inflating: lips_dataset/mask/mask00023910.png
#   inflating: lips_dataset/mask/mask00023911.png
#   inflating: lips_dataset/mask/mask00023912.png
#   inflating: lips_dataset/mask/mask00023913.png
#   inflating: lips_dataset/mask/mask00023914.png
#   inflating: lips_dataset/mask/mask00023915.png
#   inflating: lips_dataset/mask/mask00023916.png
#   inflating: lips_dataset/mask/mask00023917.png
#   inflating: lips_dataset/mask/mask00023918.png
#   inflating: lips_dataset/mask/mask00023919.png
#   inflating: lips_dataset/mask/mask00023920.png
#   inflating: lips_dataset/mask/mask00023921.png
#   inflating: lips_dataset/mask/mask00023922.png
#   inflating: lips_dataset/mask/mask00023923.png
#   inflating: lips_dataset/mask/mask00023924.png
#   inflating: lips_dataset/mask/mask00023925.png
#   inflating: lips_dataset/mask/mask00023926.png
#   inflating: lips_dataset/mask/mask00023927.png
#   inflating: lips_dataset/mask/mask00023928.png
#   inflating: lips_dataset/mask/mask00023929.png
#   inflating: lips_dataset/mask/mask00023930.png
#   inflating: lips_dataset/mask/mask00023931.png
#   inflating: lips_dataset/mask/mask00023932.png
#   inflating: lips_dataset/mask/mask00023933.png
#   inflating: lips_dataset/mask/mask00023934.png
#   inflating: lips_dataset/mask/mask00023935.png
#   inflating: lips_dataset/mask/mask00023936.png
#   inflating: lips_dataset/mask/mask00023937.png
#   inflating: lips_dataset/mask/mask00023938.png
#   inflating: lips_dataset/mask/mask00023939.png
#   inflating: lips_dataset/mask/mask00023940.png
#   inflating: lips_dataset/mask/mask00023941.png
#   inflating: lips_dataset/mask/mask00023942.png
#   inflating: lips_dataset/mask/mask00023943.png
#   inflating: lips_dataset/mask/mask00023944.png
#   inflating: lips_dataset/mask/mask00023945.png
#   inflating: lips_dataset/mask/mask00023946.png
#   inflating: lips_dataset/mask/mask00023947.png
#   inflating: lips_dataset/mask/mask00023948.png
#   inflating: lips_dataset/mask/mask00023949.png
#   inflating: lips_dataset/mask/mask00023950.png
#   inflating: lips_dataset/mask/mask00023951.png
#   inflating: lips_dataset/mask/mask00023952.png
#   inflating: lips_dataset/mask/mask00023953.png
#   inflating: lips_dataset/mask/mask00023954.png
#   inflating: lips_dataset/mask/mask00023955.png
#   inflating: lips_dataset/mask/mask00023956.png
#   inflating: lips_dataset/mask/mask00023957.png
#   inflating: lips_dataset/mask/mask00023958.png
#   inflating: lips_dataset/mask/mask00023959.png
#   inflating: lips_dataset/mask/mask00023960.png
#   inflating: lips_dataset/mask/mask00023961.png
#   inflating: lips_dataset/mask/mask00023962.png
#   inflating: lips_dataset/mask/mask00023963.png
#   inflating: lips_dataset/mask/mask00023964.png
#   inflating: lips_dataset/mask/mask00023965.png
#   inflating: lips_dataset/mask/mask00023966.png
#   inflating: lips_dataset/mask/mask00023967.png
#   inflating: lips_dataset/mask/mask00023968.png
#   inflating: lips_dataset/mask/mask00023969.png
#   inflating: lips_dataset/mask/mask00023970.png
#   inflating: lips_dataset/mask/mask00023971.png
#   inflating: lips_dataset/mask/mask00023972.png
#   inflating: lips_dataset/mask/mask00023973.png
#   inflating: lips_dataset/mask/mask00023974.png
#   inflating: lips_dataset/mask/mask00023975.png
#   inflating: lips_dataset/mask/mask00023976.png
#   inflating: lips_dataset/mask/mask00023977.png
#   inflating: lips_dataset/mask/mask00023978.png
#   inflating: lips_dataset/mask/mask00023979.png
#   inflating: lips_dataset/mask/mask00023980.png
#   inflating: lips_dataset/mask/mask00023981.png
#   inflating: lips_dataset/mask/mask00023982.png
#   inflating: lips_dataset/mask/mask00023983.png
#   inflating: lips_dataset/mask/mask00023984.png
#   inflating: lips_dataset/mask/mask00023985.png
#   inflating: lips_dataset/mask/mask00023986.png
#   inflating: lips_dataset/mask/mask00023987.png
#   inflating: lips_dataset/mask/mask00023988.png
#   inflating: lips_dataset/mask/mask00023989.png
#   inflating: lips_dataset/mask/mask00023990.png
#   inflating: lips_dataset/mask/mask00023991.png
#   inflating: lips_dataset/mask/mask00023992.png
#   inflating: lips_dataset/mask/mask00023993.png
#   inflating: lips_dataset/mask/mask00023994.png
#   inflating: lips_dataset/mask/mask00023995.png
#   inflating: lips_dataset/mask/mask00023996.png
#   inflating: lips_dataset/mask/mask00023997.png
#   inflating: lips_dataset/mask/mask00023998.png
#   inflating: lips_dataset/mask/mask00023999.png
#   inflating: lips_dataset/mask/mask00024000.png
#   inflating: lips_dataset/mask/mask00024001.png
#   inflating: lips_dataset/mask/mask00024002.png
#   inflating: lips_dataset/mask/mask00024003.png
#   inflating: lips_dataset/mask/mask00024004.png
#   inflating: lips_dataset/mask/mask00024005.png
#   inflating: lips_dataset/mask/mask00024006.png
#   inflating: lips_dataset/mask/mask00024007.png
#   inflating: lips_dataset/mask/mask00024008.png
#   inflating: lips_dataset/mask/mask00024009.png
#   inflating: lips_dataset/mask/mask00024010.png
#   inflating: lips_dataset/mask/mask00024011.png
#   inflating: lips_dataset/mask/mask00024012.png
#   inflating: lips_dataset/mask/mask00024013.png
#   inflating: lips_dataset/mask/mask00024014.png
#   inflating: lips_dataset/mask/mask00024015.png
#   inflating: lips_dataset/mask/mask00024016.png
#   inflating: lips_dataset/mask/mask00024017.png
#   inflating: lips_dataset/mask/mask00024018.png
#   inflating: lips_dataset/mask/mask00024019.png
#   inflating: lips_dataset/mask/mask00024020.png
#   inflating: lips_dataset/mask/mask00024021.png
#   inflating: lips_dataset/mask/mask00024022.png
#   inflating: lips_dataset/mask/mask00024023.png
#   inflating: lips_dataset/mask/mask00024024.png
#   inflating: lips_dataset/mask/mask00024025.png
#   inflating: lips_dataset/mask/mask00024026.png
#   inflating: lips_dataset/mask/mask00024027.png
#   inflating: lips_dataset/mask/mask00024028.png
#   inflating: lips_dataset/mask/mask00024029.png
#   inflating: lips_dataset/mask/mask00024030.png
#   inflating: lips_dataset/mask/mask00024031.png
#   inflating: lips_dataset/mask/mask00024032.png
#   inflating: lips_dataset/mask/mask00024033.png
#   inflating: lips_dataset/mask/mask00024034.png
#   inflating: lips_dataset/mask/mask00024035.png
#   inflating: lips_dataset/mask/mask00024036.png
#   inflating: lips_dataset/mask/mask00024037.png
#   inflating: lips_dataset/mask/mask00024038.png
#   inflating: lips_dataset/mask/mask00024039.png
#   inflating: lips_dataset/mask/mask00024040.png
#   inflating: lips_dataset/mask/mask00024041.png
#   inflating: lips_dataset/mask/mask00024042.png
#   inflating: lips_dataset/mask/mask00024043.png
#   inflating: lips_dataset/mask/mask00024044.png
#   inflating: lips_dataset/mask/mask00024045.png
#   inflating: lips_dataset/mask/mask00024046.png
#   inflating: lips_dataset/mask/mask00024047.png
#   inflating: lips_dataset/mask/mask00024048.png
#   inflating: lips_dataset/mask/mask00024049.png
#   inflating: lips_dataset/mask/mask00024050.png
#   inflating: lips_dataset/mask/mask00024051.png
#   inflating: lips_dataset/mask/mask00024052.png
#   inflating: lips_dataset/mask/mask00024053.png
#   inflating: lips_dataset/mask/mask00024054.png
#   inflating: lips_dataset/mask/mask00024055.png
#   inflating: lips_dataset/mask/mask00024056.png
#   inflating: lips_dataset/mask/mask00024057.png
#   inflating: lips_dataset/mask/mask00024058.png
#   inflating: lips_dataset/mask/mask00024059.png
#   inflating: lips_dataset/mask/mask00024060.png
#   inflating: lips_dataset/mask/mask00024061.png
#   inflating: lips_dataset/mask/mask00024062.png
#   inflating: lips_dataset/mask/mask00024063.png
#   inflating: lips_dataset/mask/mask00024064.png
#   inflating: lips_dataset/mask/mask00024065.png
#   inflating: lips_dataset/mask/mask00024066.png
#   inflating: lips_dataset/mask/mask00024067.png
#   inflating: lips_dataset/mask/mask00024068.png
#   inflating: lips_dataset/mask/mask00024069.png
#   inflating: lips_dataset/mask/mask00024070.png
#   inflating: lips_dataset/mask/mask00024071.png
#   inflating: lips_dataset/mask/mask00024072.png
#   inflating: lips_dataset/mask/mask00024073.png
#   inflating: lips_dataset/mask/mask00024074.png
#   inflating: lips_dataset/mask/mask00024075.png
#   inflating: lips_dataset/mask/mask00024076.png
#   inflating: lips_dataset/mask/mask00024077.png
#   inflating: lips_dataset/mask/mask00024078.png
#   inflating: lips_dataset/mask/mask00024079.png
#   inflating: lips_dataset/mask/mask00024080.png
#   inflating: lips_dataset/mask/mask00024081.png
#   inflating: lips_dataset/mask/mask00024082.png
#   inflating: lips_dataset/mask/mask00024083.png
#   inflating: lips_dataset/mask/mask00024084.png
#   inflating: lips_dataset/mask/mask00024085.png
#   inflating: lips_dataset/mask/mask00024086.png
#   inflating: lips_dataset/mask/mask00024087.png
#   inflating: lips_dataset/mask/mask00024088.png
#   inflating: lips_dataset/mask/mask00024089.png
#   inflating: lips_dataset/mask/mask00024090.png
#   inflating: lips_dataset/mask/mask00024091.png
#   inflating: lips_dataset/mask/mask00024092.png
#   inflating: lips_dataset/mask/mask00024093.png
#   inflating: lips_dataset/mask/mask00024094.png
#   inflating: lips_dataset/mask/mask00024095.png
#   inflating: lips_dataset/mask/mask00024096.png
#   inflating: lips_dataset/mask/mask00024097.png
#   inflating: lips_dataset/mask/mask00024098.png
#   inflating: lips_dataset/mask/mask00024099.png
#   inflating: lips_dataset/mask/mask00024100.png
#   inflating: lips_dataset/mask/mask00024101.png
#   inflating: lips_dataset/mask/mask00024102.png
#   inflating: lips_dataset/mask/mask00024103.png
#   inflating: lips_dataset/mask/mask00024104.png
#   inflating: lips_dataset/mask/mask00024105.png
#   inflating: lips_dataset/mask/mask00024106.png
#   inflating: lips_dataset/mask/mask00024107.png
#   inflating: lips_dataset/mask/mask00024108.png
#   inflating: lips_dataset/mask/mask00024109.png
#   inflating: lips_dataset/mask/mask00024110.png
#   inflating: lips_dataset/mask/mask00024111.png
#   inflating: lips_dataset/mask/mask00024112.png
#   inflating: lips_dataset/mask/mask00024113.png
#   inflating: lips_dataset/mask/mask00024114.png
#   inflating: lips_dataset/mask/mask00024115.png
#   inflating: lips_dataset/mask/mask00024116.png
#   inflating: lips_dataset/mask/mask00024117.png
#   inflating: lips_dataset/mask/mask00024118.png
#   inflating: lips_dataset/mask/mask00024119.png
#   inflating: lips_dataset/mask/mask00024120.png
#   inflating: lips_dataset/mask/mask00024121.png
#   inflating: lips_dataset/mask/mask00024122.png
#   inflating: lips_dataset/mask/mask00024123.png
#   inflating: lips_dataset/mask/mask00024124.png
#   inflating: lips_dataset/mask/mask00024125.png
#   inflating: lips_dataset/mask/mask00024126.png
#   inflating: lips_dataset/mask/mask00024127.png
#   inflating: lips_dataset/mask/mask00024128.png
#   inflating: lips_dataset/mask/mask00024129.png
#   inflating: lips_dataset/mask/mask00024130.png
#   inflating: lips_dataset/mask/mask00024131.png
#   inflating: lips_dataset/mask/mask00024132.png
#   inflating: lips_dataset/mask/mask00024133.png
#   inflating: lips_dataset/mask/mask00024134.png
#   inflating: lips_dataset/mask/mask00024135.png
#   inflating: lips_dataset/mask/mask00024136.png
#   inflating: lips_dataset/mask/mask00024137.png
#   inflating: lips_dataset/mask/mask00024138.png
#   inflating: lips_dataset/mask/mask00024139.png
#   inflating: lips_dataset/mask/mask00024140.png
#   inflating: lips_dataset/mask/mask00024141.png
#   inflating: lips_dataset/mask/mask00024142.png
#   inflating: lips_dataset/mask/mask00024143.png
#   inflating: lips_dataset/mask/mask00024144.png
#   inflating: lips_dataset/mask/mask00024145.png
#   inflating: lips_dataset/mask/mask00024146.png
#   inflating: lips_dataset/mask/mask00024147.png
#   inflating: lips_dataset/mask/mask00024148.png
#   inflating: lips_dataset/mask/mask00024149.png
#   inflating: lips_dataset/mask/mask00024150.png
#   inflating: lips_dataset/mask/mask00024151.png
#   inflating: lips_dataset/mask/mask00024152.png
#   inflating: lips_dataset/mask/mask00024153.png
#   inflating: lips_dataset/mask/mask00024154.png
#   inflating: lips_dataset/mask/mask00024155.png
#   inflating: lips_dataset/mask/mask00024156.png
#   inflating: lips_dataset/mask/mask00024157.png
#   inflating: lips_dataset/mask/mask00024158.png
#   inflating: lips_dataset/mask/mask00024159.png
#   inflating: lips_dataset/mask/mask00024160.png
#   inflating: lips_dataset/mask/mask00024161.png
#   inflating: lips_dataset/mask/mask00024162.png
#   inflating: lips_dataset/mask/mask00024163.png
#   inflating: lips_dataset/mask/mask00024164.png
#   inflating: lips_dataset/mask/mask00024165.png
#   inflating: lips_dataset/mask/mask00024166.png
#   inflating: lips_dataset/mask/mask00024167.png
#   inflating: lips_dataset/mask/mask00024168.png
#   inflating: lips_dataset/mask/mask00024169.png
#   inflating: lips_dataset/mask/mask00024170.png
#   inflating: lips_dataset/mask/mask00024171.png
#   inflating: lips_dataset/mask/mask00024172.png
#   inflating: lips_dataset/mask/mask00024173.png
#   inflating: lips_dataset/mask/mask00024174.png
#   inflating: lips_dataset/mask/mask00024175.png
#   inflating: lips_dataset/mask/mask00024176.png
#   inflating: lips_dataset/mask/mask00024177.png
#   inflating: lips_dataset/mask/mask00024178.png
#   inflating: lips_dataset/mask/mask00024179.png
#   inflating: lips_dataset/mask/mask00024180.png
#   inflating: lips_dataset/mask/mask00024181.png
#   inflating: lips_dataset/mask/mask00024182.png
#   inflating: lips_dataset/mask/mask00024183.png
#   inflating: lips_dataset/mask/mask00024184.png
#   inflating: lips_dataset/mask/mask00024185.png
#   inflating: lips_dataset/mask/mask00024186.png
#   inflating: lips_dataset/mask/mask00024187.png
#   inflating: lips_dataset/mask/mask00024188.png
#   inflating: lips_dataset/mask/mask00024189.png
#   inflating: lips_dataset/mask/mask00024190.png
#   inflating: lips_dataset/mask/mask00024191.png
#   inflating: lips_dataset/mask/mask00024192.png
#   inflating: lips_dataset/mask/mask00024193.png
#   inflating: lips_dataset/mask/mask00024194.png
#   inflating: lips_dataset/mask/mask00024195.png
#   inflating: lips_dataset/mask/mask00024196.png
#   inflating: lips_dataset/mask/mask00024197.png
#   inflating: lips_dataset/mask/mask00024198.png
#   inflating: lips_dataset/mask/mask00024199.png
#   inflating: lips_dataset/mask/mask00024200.png
#   inflating: lips_dataset/mask/mask00024201.png
#   inflating: lips_dataset/mask/mask00024202.png
#   inflating: lips_dataset/mask/mask00024203.png
#   inflating: lips_dataset/mask/mask00024204.png
#   inflating: lips_dataset/mask/mask00024205.png
#   inflating: lips_dataset/mask/mask00024206.png
#   inflating: lips_dataset/mask/mask00024207.png
#   inflating: lips_dataset/mask/mask00024208.png
#   inflating: lips_dataset/mask/mask00024209.png
#   inflating: lips_dataset/mask/mask00024210.png
#   inflating: lips_dataset/mask/mask00024211.png
#   inflating: lips_dataset/mask/mask00024212.png
#   inflating: lips_dataset/mask/mask00024213.png
#   inflating: lips_dataset/mask/mask00024214.png
#   inflating: lips_dataset/mask/mask00024215.png
#   inflating: lips_dataset/mask/mask00024216.png
#   inflating: lips_dataset/mask/mask00024217.png
#   inflating: lips_dataset/mask/mask00024218.png
#   inflating: lips_dataset/mask/mask00024219.png
#   inflating: lips_dataset/mask/mask00024220.png
#   inflating: lips_dataset/mask/mask00024221.png
#   inflating: lips_dataset/mask/mask00024222.png
#   inflating: lips_dataset/mask/mask00024223.png
#   inflating: lips_dataset/mask/mask00024224.png
#   inflating: lips_dataset/mask/mask00024225.png
#   inflating: lips_dataset/mask/mask00024226.png
#   inflating: lips_dataset/mask/mask00024227.png
#   inflating: lips_dataset/mask/mask00024228.png
#   inflating: lips_dataset/mask/mask00024229.png
#   inflating: lips_dataset/mask/mask00024230.png
#   inflating: lips_dataset/mask/mask00024231.png
#   inflating: lips_dataset/mask/mask00024232.png
#   inflating: lips_dataset/mask/mask00024233.png
#   inflating: lips_dataset/mask/mask00024234.png
#   inflating: lips_dataset/mask/mask00024235.png
#   inflating: lips_dataset/mask/mask00024236.png
#   inflating: lips_dataset/mask/mask00024237.png
#   inflating: lips_dataset/mask/mask00024238.png
#   inflating: lips_dataset/mask/mask00024239.png
#   inflating: lips_dataset/mask/mask00024240.png
#   inflating: lips_dataset/mask/mask00024241.png
#   inflating: lips_dataset/mask/mask00024242.png
#   inflating: lips_dataset/mask/mask00024243.png
#   inflating: lips_dataset/mask/mask00024244.png
#   inflating: lips_dataset/mask/mask00024245.png
#   inflating: lips_dataset/mask/mask00024246.png
#   inflating: lips_dataset/mask/mask00024247.png
#   inflating: lips_dataset/mask/mask00024248.png
#   inflating: lips_dataset/mask/mask00024249.png
#   inflating: lips_dataset/mask/mask00024250.png
#   inflating: lips_dataset/mask/mask00024251.png
#   inflating: lips_dataset/mask/mask00024252.png
#   inflating: lips_dataset/mask/mask00024253.png
#   inflating: lips_dataset/mask/mask00024254.png
#   inflating: lips_dataset/mask/mask00024255.png
#   inflating: lips_dataset/mask/mask00024256.png
#   inflating: lips_dataset/mask/mask00024257.png
#   inflating: lips_dataset/mask/mask00024258.png
#   inflating: lips_dataset/mask/mask00024259.png
#   inflating: lips_dataset/mask/mask00024260.png
#   inflating: lips_dataset/mask/mask00024261.png
#   inflating: lips_dataset/mask/mask00024262.png
#   inflating: lips_dataset/mask/mask00024263.png
#   inflating: lips_dataset/mask/mask00024264.png
#   inflating: lips_dataset/mask/mask00024265.png
#   inflating: lips_dataset/mask/mask00024266.png
#   inflating: lips_dataset/mask/mask00024267.png
#   inflating: lips_dataset/mask/mask00024268.png
#   inflating: lips_dataset/mask/mask00024269.png
#   inflating: lips_dataset/mask/mask00024270.png
#   inflating: lips_dataset/mask/mask00024271.png
#   inflating: lips_dataset/mask/mask00024272.png
#   inflating: lips_dataset/mask/mask00024273.png
#   inflating: lips_dataset/mask/mask00024274.png
#   inflating: lips_dataset/mask/mask00024275.png
#   inflating: lips_dataset/mask/mask00024276.png
#   inflating: lips_dataset/mask/mask00024277.png
#   inflating: lips_dataset/mask/mask00024278.png
#   inflating: lips_dataset/mask/mask00024279.png
#   inflating: lips_dataset/mask/mask00024280.png
#   inflating: lips_dataset/mask/mask00024281.png
#   inflating: lips_dataset/mask/mask00024282.png
#   inflating: lips_dataset/mask/mask00024283.png
#   inflating: lips_dataset/mask/mask00024284.png
#   inflating: lips_dataset/mask/mask00024285.png
#   inflating: lips_dataset/mask/mask00024286.png
#   inflating: lips_dataset/mask/mask00024287.png
#   inflating: lips_dataset/mask/mask00024288.png
#   inflating: lips_dataset/mask/mask00024289.png
#   inflating: lips_dataset/mask/mask00024290.png
#   inflating: lips_dataset/mask/mask00024291.png
#   inflating: lips_dataset/mask/mask00024292.png
#   inflating: lips_dataset/mask/mask00024293.png
#   inflating: lips_dataset/mask/mask00024294.png
#   inflating: lips_dataset/mask/mask00024295.png
#   inflating: lips_dataset/mask/mask00024296.png
#   inflating: lips_dataset/mask/mask00024297.png
#   inflating: lips_dataset/mask/mask00024298.png
#   inflating: lips_dataset/mask/mask00024299.png
#   inflating: lips_dataset/mask/mask00024300.png
#   inflating: lips_dataset/mask/mask00024301.png
#   inflating: lips_dataset/mask/mask00024302.png
#   inflating: lips_dataset/mask/mask00024303.png
#   inflating: lips_dataset/mask/mask00024304.png
#   inflating: lips_dataset/mask/mask00024305.png
#   inflating: lips_dataset/mask/mask00024306.png
#   inflating: lips_dataset/mask/mask00024307.png
#   inflating: lips_dataset/mask/mask00024308.png
#   inflating: lips_dataset/mask/mask00024309.png
#   inflating: lips_dataset/mask/mask00024310.png
#   inflating: lips_dataset/mask/mask00024311.png
#   inflating: lips_dataset/mask/mask00024312.png
#   inflating: lips_dataset/mask/mask00024313.png
#   inflating: lips_dataset/mask/mask00024314.png
#   inflating: lips_dataset/mask/mask00024315.png
#   inflating: lips_dataset/mask/mask00024316.png
#   inflating: lips_dataset/mask/mask00024317.png
#   inflating: lips_dataset/mask/mask00024318.png
#   inflating: lips_dataset/mask/mask00024319.png
#   inflating: lips_dataset/mask/mask00024320.png
#   inflating: lips_dataset/mask/mask00024321.png
#   inflating: lips_dataset/mask/mask00024322.png
#   inflating: lips_dataset/mask/mask00024323.png
#   inflating: lips_dataset/mask/mask00024324.png
#   inflating: lips_dataset/mask/mask00024325.png
#   inflating: lips_dataset/mask/mask00024326.png
#   inflating: lips_dataset/mask/mask00024327.png
#   inflating: lips_dataset/mask/mask00024328.png
#   inflating: lips_dataset/mask/mask00024329.png
#   inflating: lips_dataset/mask/mask00024330.png
#   inflating: lips_dataset/mask/mask00024331.png
#   inflating: lips_dataset/mask/mask00024332.png
#   inflating: lips_dataset/mask/mask00024333.png
#   inflating: lips_dataset/mask/mask00024334.png
#   inflating: lips_dataset/mask/mask00024335.png
#   inflating: lips_dataset/mask/mask00024336.png
#   inflating: lips_dataset/mask/mask00024337.png
#   inflating: lips_dataset/mask/mask00024338.png
#   inflating: lips_dataset/mask/mask00024339.png
#   inflating: lips_dataset/mask/mask00024340.png
#   inflating: lips_dataset/mask/mask00024341.png
#   inflating: lips_dataset/mask/mask00024342.png
#   inflating: lips_dataset/mask/mask00024343.png
#   inflating: lips_dataset/mask/mask00024344.png
#   inflating: lips_dataset/mask/mask00024345.png
#   inflating: lips_dataset/mask/mask00024346.png
#   inflating: lips_dataset/mask/mask00024347.png
#   inflating: lips_dataset/mask/mask00024348.png
#   inflating: lips_dataset/mask/mask00024349.png
#   inflating: lips_dataset/mask/mask00024350.png
#   inflating: lips_dataset/mask/mask00024351.png
#   inflating: lips_dataset/mask/mask00024352.png
#   inflating: lips_dataset/mask/mask00024353.png
#   inflating: lips_dataset/mask/mask00024354.png
#   inflating: lips_dataset/mask/mask00024355.png
#   inflating: lips_dataset/mask/mask00024356.png
#   inflating: lips_dataset/mask/mask00024357.png
#   inflating: lips_dataset/mask/mask00024358.png
#   inflating: lips_dataset/mask/mask00024359.png
#   inflating: lips_dataset/mask/mask00024360.png
#   inflating: lips_dataset/mask/mask00024361.png
#   inflating: lips_dataset/mask/mask00024362.png
#   inflating: lips_dataset/mask/mask00024363.png
#   inflating: lips_dataset/mask/mask00024364.png
#   inflating: lips_dataset/mask/mask00024365.png
#   inflating: lips_dataset/mask/mask00024366.png
#   inflating: lips_dataset/mask/mask00024367.png
#   inflating: lips_dataset/mask/mask00024368.png
#   inflating: lips_dataset/mask/mask00024369.png
#   inflating: lips_dataset/mask/mask00024370.png
#   inflating: lips_dataset/mask/mask00024371.png
#   inflating: lips_dataset/mask/mask00024372.png
#   inflating: lips_dataset/mask/mask00024373.png
#   inflating: lips_dataset/mask/mask00024374.png
#   inflating: lips_dataset/mask/mask00024375.png
#   inflating: lips_dataset/mask/mask00024376.png
#   inflating: lips_dataset/mask/mask00024377.png
#   inflating: lips_dataset/mask/mask00024378.png
#   inflating: lips_dataset/mask/mask00024379.png
#   inflating: lips_dataset/mask/mask00024380.png
#   inflating: lips_dataset/mask/mask00024381.png
#   inflating: lips_dataset/mask/mask00024382.png
#   inflating: lips_dataset/mask/mask00024383.png
#   inflating: lips_dataset/mask/mask00024384.png
#   inflating: lips_dataset/mask/mask00024385.png
#   inflating: lips_dataset/mask/mask00024386.png
#   inflating: lips_dataset/mask/mask00024387.png
#   inflating: lips_dataset/mask/mask00024388.png
#   inflating: lips_dataset/mask/mask00024389.png
#   inflating: lips_dataset/mask/mask00024390.png
#   inflating: lips_dataset/mask/mask00024391.png
#   inflating: lips_dataset/mask/mask00024392.png
#   inflating: lips_dataset/mask/mask00024393.png
#   inflating: lips_dataset/mask/mask00024394.png
#   inflating: lips_dataset/mask/mask00024395.png
#   inflating: lips_dataset/mask/mask00024396.png
#   inflating: lips_dataset/mask/mask00024397.png
#   inflating: lips_dataset/mask/mask00024398.png
#   inflating: lips_dataset/mask/mask00024399.png
#   inflating: lips_dataset/mask/mask00024400.png
#   inflating: lips_dataset/mask/mask00024401.png
#   inflating: lips_dataset/mask/mask00024402.png
#   inflating: lips_dataset/mask/mask00024403.png
#   inflating: lips_dataset/mask/mask00024404.png
#   inflating: lips_dataset/mask/mask00024405.png
#   inflating: lips_dataset/mask/mask00024406.png
#   inflating: lips_dataset/mask/mask00024407.png
#   inflating: lips_dataset/mask/mask00024408.png
#   inflating: lips_dataset/mask/mask00024409.png
#   inflating: lips_dataset/mask/mask00024410.png
#   inflating: lips_dataset/mask/mask00024411.png
#   inflating: lips_dataset/mask/mask00024412.png
#   inflating: lips_dataset/mask/mask00024413.png
#   inflating: lips_dataset/mask/mask00024414.png
#   inflating: lips_dataset/mask/mask00024415.png
#   inflating: lips_dataset/mask/mask00024416.png
#   inflating: lips_dataset/mask/mask00024417.png
#   inflating: lips_dataset/mask/mask00024418.png
#   inflating: lips_dataset/mask/mask00024419.png
#   inflating: lips_dataset/mask/mask00024420.png
#   inflating: lips_dataset/mask/mask00024421.png
#   inflating: lips_dataset/mask/mask00024422.png
#   inflating: lips_dataset/mask/mask00024423.png
#   inflating: lips_dataset/mask/mask00024424.png
#   inflating: lips_dataset/mask/mask00024425.png
#   inflating: lips_dataset/mask/mask00024426.png
#   inflating: lips_dataset/mask/mask00024427.png
#   inflating: lips_dataset/mask/mask00024428.png
#   inflating: lips_dataset/mask/mask00024429.png
#   inflating: lips_dataset/mask/mask00024430.png
#   inflating: lips_dataset/mask/mask00024431.png
#   inflating: lips_dataset/mask/mask00024432.png
#   inflating: lips_dataset/mask/mask00024433.png
#   inflating: lips_dataset/mask/mask00024434.png
#   inflating: lips_dataset/mask/mask00024435.png
#   inflating: lips_dataset/mask/mask00024436.png
#   inflating: lips_dataset/mask/mask00024437.png
#   inflating: lips_dataset/mask/mask00024438.png
#   inflating: lips_dataset/mask/mask00024439.png
#   inflating: lips_dataset/mask/mask00024440.png
#   inflating: lips_dataset/mask/mask00024441.png
#   inflating: lips_dataset/mask/mask00024442.png
#   inflating: lips_dataset/mask/mask00024443.png
#   inflating: lips_dataset/mask/mask00024444.png
#   inflating: lips_dataset/mask/mask00024445.png
#   inflating: lips_dataset/mask/mask00024446.png
#   inflating: lips_dataset/mask/mask00024447.png
#   inflating: lips_dataset/mask/mask00024448.png
#   inflating: lips_dataset/mask/mask00024449.png
#   inflating: lips_dataset/mask/mask00024450.png
#   inflating: lips_dataset/mask/mask00024451.png
#   inflating: lips_dataset/mask/mask00024452.png
#   inflating: lips_dataset/mask/mask00024453.png
#   inflating: lips_dataset/mask/mask00024454.png
#   inflating: lips_dataset/mask/mask00024455.png
#   inflating: lips_dataset/mask/mask00024456.png
#   inflating: lips_dataset/mask/mask00024457.png
#   inflating: lips_dataset/mask/mask00024458.png
#   inflating: lips_dataset/mask/mask00024459.png
#   inflating: lips_dataset/mask/mask00024460.png
#   inflating: lips_dataset/mask/mask00024461.png
#   inflating: lips_dataset/mask/mask00024462.png
#   inflating: lips_dataset/mask/mask00024463.png
#   inflating: lips_dataset/mask/mask00024464.png
#   inflating: lips_dataset/mask/mask00024465.png
#   inflating: lips_dataset/mask/mask00024466.png
#   inflating: lips_dataset/mask/mask00024467.png
#   inflating: lips_dataset/mask/mask00024468.png
#   inflating: lips_dataset/mask/mask00024469.png
#   inflating: lips_dataset/mask/mask00024470.png
#   inflating: lips_dataset/mask/mask00024471.png
#   inflating: lips_dataset/mask/mask00024472.png
#   inflating: lips_dataset/mask/mask00024473.png
#   inflating: lips_dataset/mask/mask00024474.png
#   inflating: lips_dataset/mask/mask00024475.png
#   inflating: lips_dataset/mask/mask00024476.png
#   inflating: lips_dataset/mask/mask00024477.png
#   inflating: lips_dataset/mask/mask00024478.png
#   inflating: lips_dataset/mask/mask00024479.png
#   inflating: lips_dataset/mask/mask00024480.png
#   inflating: lips_dataset/mask/mask00024481.png
#   inflating: lips_dataset/mask/mask00024482.png
#   inflating: lips_dataset/mask/mask00024483.png
#   inflating: lips_dataset/mask/mask00024484.png
#   inflating: lips_dataset/mask/mask00024485.png
#   inflating: lips_dataset/mask/mask00024486.png
#   inflating: lips_dataset/mask/mask00024487.png
#   inflating: lips_dataset/mask/mask00024488.png
#   inflating: lips_dataset/mask/mask00024489.png
#   inflating: lips_dataset/mask/mask00024490.png
#   inflating: lips_dataset/mask/mask00024491.png
#   inflating: lips_dataset/mask/mask00024492.png
#   inflating: lips_dataset/mask/mask00024493.png
#   inflating: lips_dataset/mask/mask00024494.png
#   inflating: lips_dataset/mask/mask00024495.png
#   inflating: lips_dataset/mask/mask00024496.png
#   inflating: lips_dataset/mask/mask00024497.png
#   inflating: lips_dataset/mask/mask00024498.png
#   inflating: lips_dataset/mask/mask00024499.png
#   inflating: lips_dataset/mask/mask00024500.png
#   inflating: lips_dataset/mask/mask00024501.png
#   inflating: lips_dataset/mask/mask00024502.png
#   inflating: lips_dataset/mask/mask00024503.png
#   inflating: lips_dataset/mask/mask00024504.png
#   inflating: lips_dataset/mask/mask00024505.png
#   inflating: lips_dataset/mask/mask00024506.png
#   inflating: lips_dataset/mask/mask00024507.png
#   inflating: lips_dataset/mask/mask00024508.png
#   inflating: lips_dataset/mask/mask00024509.png
#   inflating: lips_dataset/mask/mask00024510.png
#   inflating: lips_dataset/mask/mask00024511.png
#   inflating: lips_dataset/mask/mask00024512.png
#   inflating: lips_dataset/mask/mask00024513.png
#   inflating: lips_dataset/mask/mask00024514.png
#   inflating: lips_dataset/mask/mask00024515.png
#   inflating: lips_dataset/mask/mask00024516.png
#   inflating: lips_dataset/mask/mask00024517.png
#   inflating: lips_dataset/mask/mask00024518.png
#   inflating: lips_dataset/mask/mask00024519.png
#   inflating: lips_dataset/mask/mask00024520.png
#   inflating: lips_dataset/mask/mask00024521.png
#   inflating: lips_dataset/mask/mask00024522.png
#   inflating: lips_dataset/mask/mask00024523.png
#   inflating: lips_dataset/mask/mask00024524.png
#   inflating: lips_dataset/mask/mask00024525.png
#   inflating: lips_dataset/mask/mask00024526.png
#   inflating: lips_dataset/mask/mask00024527.png
#   inflating: lips_dataset/mask/mask00024528.png
#   inflating: lips_dataset/mask/mask00024529.png
#   inflating: lips_dataset/mask/mask00024530.png
#   inflating: lips_dataset/mask/mask00024531.png
#   inflating: lips_dataset/mask/mask00024532.png
#   inflating: lips_dataset/mask/mask00024533.png
#   inflating: lips_dataset/mask/mask00024534.png
#   inflating: lips_dataset/mask/mask00024535.png
#   inflating: lips_dataset/mask/mask00024536.png
#   inflating: lips_dataset/mask/mask00024537.png
#   inflating: lips_dataset/mask/mask00024538.png
#   inflating: lips_dataset/mask/mask00024539.png
#   inflating: lips_dataset/mask/mask00024540.png
#   inflating: lips_dataset/mask/mask00024541.png
#   inflating: lips_dataset/mask/mask00024542.png
#   inflating: lips_dataset/mask/mask00024543.png
#   inflating: lips_dataset/mask/mask00024544.png
#   inflating: lips_dataset/mask/mask00024545.png
#   inflating: lips_dataset/mask/mask00024546.png
#   inflating: lips_dataset/mask/mask00024547.png
#   inflating: lips_dataset/mask/mask00024548.png
#   inflating: lips_dataset/mask/mask00024549.png
#   inflating: lips_dataset/mask/mask00024550.png
#   inflating: lips_dataset/mask/mask00024551.png
#   inflating: lips_dataset/mask/mask00024552.png
# ...
#   inflating: lips_dataset/mask/mask00028275.png
#   inflating: lips_dataset/mask/mask00028276.png
#   inflating: lips_dataset/mask/mask00028277.png
#   inflating: lips_dataset/mask/mask00028278.png
#   inflating: lips_dataset/mask/mask00028279.png
#   inflating: lips_dataset/mask/mask00028280.png
#   inflating: lips_dataset/mask/mask00028281.png
#   inflating: lips_dataset/mask/mask00028282.png
#   inflating: lips_dataset/mask/mask00028283.png
#   inflating: lips_dataset/mask/mask00028284.png
#   inflating: lips_dataset/mask/mask00028285.png
#   inflating: lips_dataset/mask/mask00028286.png
#   inflating: lips_dataset/mask/mask00028287.png
#   inflating: lips_dataset/mask/mask00028288.png
#   inflating: lips_dataset/mask/mask00028289.png
#   inflating: lips_dataset/mask/mask00028290.png
#   inflating: lips_dataset/mask/mask00028291.png
#   inflating: lips_dataset/mask/mask00028292.png
#   inflating: lips_dataset/mask/mask00028293.png
#   inflating: lips_dataset/mask/mask00028294.png
#   inflating: lips_dataset/mask/mask00028295.png
#   inflating: lips_dataset/mask/mask00028296.png
#   inflating: lips_dataset/mask/mask00028297.png
#   inflating: lips_dataset/mask/mask00028298.png
#   inflating: lips_dataset/mask/mask00028299.png
#   inflating: lips_dataset/mask/mask00028300.png
#   inflating: lips_dataset/mask/mask00028301.png
#   inflating: lips_dataset/mask/mask00028302.png
#   inflating: lips_dataset/mask/mask00028303.png
#   inflating: lips_dataset/mask/mask00028304.png
#   inflating: lips_dataset/mask/mask00028305.png
#   inflating: lips_dataset/mask/mask00028306.png
#   inflating: lips_dataset/mask/mask00028307.png
#   inflating: lips_dataset/mask/mask00028308.png
#   inflating: lips_dataset/mask/mask00028309.png
#   inflating: lips_dataset/mask/mask00028310.png
#   inflating: lips_dataset/mask/mask00028311.png
#   inflating: lips_dataset/mask/mask00028312.png
#   inflating: lips_dataset/mask/mask00028313.png
#   inflating: lips_dataset/mask/mask00028314.png
#   inflating: lips_dataset/mask/mask00028315.png
#   inflating: lips_dataset/mask/mask00028316.png
#   inflating: lips_dataset/mask/mask00028317.png
#   inflating: lips_dataset/mask/mask00028318.png
#   inflating: lips_dataset/mask/mask00028319.png
#   inflating: lips_dataset/mask/mask00028320.png
#   inflating: lips_dataset/mask/mask00028321.png
#   inflating: lips_dataset/mask/mask00028322.png
#   inflating: lips_dataset/mask/mask00028323.png
#   inflating: lips_dataset/mask/mask00028324.png
#   inflating: lips_dataset/mask/mask00028325.png
#   inflating: lips_dataset/mask/mask00028326.png
#   inflating: lips_dataset/mask/mask00028327.png
#   inflating: lips_dataset/mask/mask00028328.png
#   inflating: lips_dataset/mask/mask00028329.png
#   inflating: lips_dataset/mask/mask00028330.png
#   inflating: lips_dataset/mask/mask00028331.png
#   inflating: lips_dataset/mask/mask00028332.png
#   inflating: lips_dataset/mask/mask00028333.png
#   inflating: lips_dataset/mask/mask00028334.png
#   inflating: lips_dataset/mask/mask00028335.png
#   inflating: lips_dataset/mask/mask00028336.png
#   inflating: lips_dataset/mask/mask00028337.png
#   inflating: lips_dataset/mask/mask00028338.png
#   inflating: lips_dataset/mask/mask00028339.png
#   inflating: lips_dataset/mask/mask00028340.png
#   inflating: lips_dataset/mask/mask00028341.png
#   inflating: lips_dataset/mask/mask00028342.png
#   inflating: lips_dataset/mask/mask00028343.png
#   inflating: lips_dataset/mask/mask00028344.png
#   inflating: lips_dataset/mask/mask00028345.png
#   inflating: lips_dataset/mask/mask00028346.png
#   inflating: lips_dataset/mask/mask00028347.png
#   inflating: lips_dataset/mask/mask00028348.png
#   inflating: lips_dataset/mask/mask00028349.png
#   inflating: lips_dataset/mask/mask00028350.png
#   inflating: lips_dataset/mask/mask00028351.png
#   inflating: lips_dataset/mask/mask00028352.png
#   inflating: lips_dataset/mask/mask00028353.png
#   inflating: lips_dataset/mask/mask00028354.png
#   inflating: lips_dataset/mask/mask00028355.png
#   inflating: lips_dataset/mask/mask00028356.png
#   inflating: lips_dataset/mask/mask00028357.png
#   inflating: lips_dataset/mask/mask00028358.png
#   inflating: lips_dataset/mask/mask00028359.png
#   inflating: lips_dataset/mask/mask00028360.png
#   inflating: lips_dataset/mask/mask00028361.png
#   inflating: lips_dataset/mask/mask00028362.png
#   inflating: lips_dataset/mask/mask00028363.png
#   inflating: lips_dataset/mask/mask00028364.png
#   inflating: lips_dataset/mask/mask00028365.png
#   inflating: lips_dataset/mask/mask00028366.png
#   inflating: lips_dataset/mask/mask00028367.png
#   inflating: lips_dataset/mask/mask00028368.png
#   inflating: lips_dataset/mask/mask00028369.png
#   inflating: lips_dataset/mask/mask00028370.png
#   inflating: lips_dataset/mask/mask00028371.png
#   inflating: lips_dataset/mask/mask00028372.png
#   inflating: lips_dataset/mask/mask00028373.png
#   inflating: lips_dataset/mask/mask00028374.png
#   inflating: lips_dataset/mask/mask00028375.png
#   inflating: lips_dataset/mask/mask00028376.png
#   inflating: lips_dataset/mask/mask00028377.png
#   inflating: lips_dataset/mask/mask00028378.png
#   inflating: lips_dataset/mask/mask00028379.png
#   inflating: lips_dataset/mask/mask00028380.png
#   inflating: lips_dataset/mask/mask00028381.png
#   inflating: lips_dataset/mask/mask00028382.png
#   inflating: lips_dataset/mask/mask00028383.png
#   inflating: lips_dataset/mask/mask00028384.png
#   inflating: lips_dataset/mask/mask00028385.png
#   inflating: lips_dataset/mask/mask00028386.png
#   inflating: lips_dataset/mask/mask00028387.png
#   inflating: lips_dataset/mask/mask00028388.png
#   inflating: lips_dataset/mask/mask00028389.png
#   inflating: lips_dataset/mask/mask00028390.png
#   inflating: lips_dataset/mask/mask00028391.png
#   inflating: lips_dataset/mask/mask00028392.png
#   inflating: lips_dataset/mask/mask00028393.png
#   inflating: lips_dataset/mask/mask00028394.png
#   inflating: lips_dataset/mask/mask00028395.png
#   inflating: lips_dataset/mask/mask00028396.png
#   inflating: lips_dataset/mask/mask00028397.png
#   inflating: lips_dataset/mask/mask00028398.png
#   inflating: lips_dataset/mask/mask00028399.png
#   inflating: lips_dataset/mask/mask00028400.png
#   inflating: lips_dataset/mask/mask00028401.png
#   inflating: lips_dataset/mask/mask00028402.png
#   inflating: lips_dataset/mask/mask00028403.png
#   inflating: lips_dataset/mask/mask00028404.png
#   inflating: lips_dataset/mask/mask00028405.png
#   inflating: lips_dataset/mask/mask00028406.png
#   inflating: lips_dataset/mask/mask00028407.png
#   inflating: lips_dataset/mask/mask00028408.png
#   inflating: lips_dataset/mask/mask00028409.png
#   inflating: lips_dataset/mask/mask00028410.png
#   inflating: lips_dataset/mask/mask00028411.png
#   inflating: lips_dataset/mask/mask00028412.png
#   inflating: lips_dataset/mask/mask00028413.png
#   inflating: lips_dataset/mask/mask00028414.png
#   inflating: lips_dataset/mask/mask00028415.png
#   inflating: lips_dataset/mask/mask00028416.png
#   inflating: lips_dataset/mask/mask00028417.png
#   inflating: lips_dataset/mask/mask00028418.png
#   inflating: lips_dataset/mask/mask00028419.png
#   inflating: lips_dataset/mask/mask00028420.png
#   inflating: lips_dataset/mask/mask00028421.png
#   inflating: lips_dataset/mask/mask00028422.png
#   inflating: lips_dataset/mask/mask00028423.png
#   inflating: lips_dataset/mask/mask00028424.png
#   inflating: lips_dataset/mask/mask00028425.png
#   inflating: lips_dataset/mask/mask00028426.png
#   inflating: lips_dataset/mask/mask00028427.png
#   inflating: lips_dataset/mask/mask00028428.png
#   inflating: lips_dataset/mask/mask00028429.png
#   inflating: lips_dataset/mask/mask00028430.png
#   inflating: lips_dataset/mask/mask00028431.png
#   inflating: lips_dataset/mask/mask00028432.png
#   inflating: lips_dataset/mask/mask00028433.png
#   inflating: lips_dataset/mask/mask00028434.png
#   inflating: lips_dataset/mask/mask00028435.png
#   inflating: lips_dataset/mask/mask00028436.png
#   inflating: lips_dataset/mask/mask00028437.png
#   inflating: lips_dataset/mask/mask00028438.png
#   inflating: lips_dataset/mask/mask00028439.png
#   inflating: lips_dataset/mask/mask00028440.png
#   inflating: lips_dataset/mask/mask00028441.png
#   inflating: lips_dataset/mask/mask00028442.png
#   inflating: lips_dataset/mask/mask00028443.png
#   inflating: lips_dataset/mask/mask00028444.png
#   inflating: lips_dataset/mask/mask00028445.png
#   inflating: lips_dataset/mask/mask00028446.png
#   inflating: lips_dataset/mask/mask00028447.png
#   inflating: lips_dataset/mask/mask00028448.png
#   inflating: lips_dataset/mask/mask00028449.png
#   inflating: lips_dataset/mask/mask00028450.png
#   inflating: lips_dataset/mask/mask00028451.png
#   inflating: lips_dataset/mask/mask00028452.png
#   inflating: lips_dataset/mask/mask00028453.png
#   inflating: lips_dataset/mask/mask00028454.png
#   inflating: lips_dataset/mask/mask00028455.png
#   inflating: lips_dataset/mask/mask00028456.png
#   inflating: lips_dataset/mask/mask00028457.png
#   inflating: lips_dataset/mask/mask00028458.png
#   inflating: lips_dataset/mask/mask00028459.png
#   inflating: lips_dataset/mask/mask00028460.png
#   inflating: lips_dataset/mask/mask00028461.png
#   inflating: lips_dataset/mask/mask00028462.png
#   inflating: lips_dataset/mask/mask00028463.png
#   inflating: lips_dataset/mask/mask00028464.png
#   inflating: lips_dataset/mask/mask00028465.png
#   inflating: lips_dataset/mask/mask00028466.png
#   inflating: lips_dataset/mask/mask00028467.png
#   inflating: lips_dataset/mask/mask00028468.png
#   inflating: lips_dataset/mask/mask00028469.png
#   inflating: lips_dataset/mask/mask00028470.png
#   inflating: lips_dataset/mask/mask00028471.png
#   inflating: lips_dataset/mask/mask00028472.png
#   inflating: lips_dataset/mask/mask00028473.png
#   inflating: lips_dataset/mask/mask00028474.png
#   inflating: lips_dataset/mask/mask00028475.png
#   inflating: lips_dataset/mask/mask00028476.png
#   inflating: lips_dataset/mask/mask00028477.png
#   inflating: lips_dataset/mask/mask00028478.png
#   inflating: lips_dataset/mask/mask00028479.png
#   inflating: lips_dataset/mask/mask00028480.png
#   inflating: lips_dataset/mask/mask00028481.png
#   inflating: lips_dataset/mask/mask00028482.png
#   inflating: lips_dataset/mask/mask00028483.png
#   inflating: lips_dataset/mask/mask00028484.png
#   inflating: lips_dataset/mask/mask00028485.png
#   inflating: lips_dataset/mask/mask00028486.png
#   inflating: lips_dataset/mask/mask00028487.png
#   inflating: lips_dataset/mask/mask00028488.png
#   inflating: lips_dataset/mask/mask00028489.png
#   inflating: lips_dataset/mask/mask00028490.png
#   inflating: lips_dataset/mask/mask00028491.png
#   inflating: lips_dataset/mask/mask00028492.png
#   inflating: lips_dataset/mask/mask00028493.png
#   inflating: lips_dataset/mask/mask00028494.png
#   inflating: lips_dataset/mask/mask00028495.png
#   inflating: lips_dataset/mask/mask00028496.png
#   inflating: lips_dataset/mask/mask00028497.png
#   inflating: lips_dataset/mask/mask00028498.png
#   inflating: lips_dataset/mask/mask00028499.png
#   inflating: lips_dataset/mask/mask00028500.png
#   inflating: lips_dataset/mask/mask00028501.png
#   inflating: lips_dataset/mask/mask00028502.png
#   inflating: lips_dataset/mask/mask00028503.png
#   inflating: lips_dataset/mask/mask00028504.png
#   inflating: lips_dataset/mask/mask00028505.png
#   inflating: lips_dataset/mask/mask00028506.png
#   inflating: lips_dataset/mask/mask00028507.png
#   inflating: lips_dataset/mask/mask00028508.png
#   inflating: lips_dataset/mask/mask00028509.png
#   inflating: lips_dataset/mask/mask00028510.png
#   inflating: lips_dataset/mask/mask00028511.png
#   inflating: lips_dataset/mask/mask00028512.png
#   inflating: lips_dataset/mask/mask00028513.png
#   inflating: lips_dataset/mask/mask00028514.png
#   inflating: lips_dataset/mask/mask00028515.png
#   inflating: lips_dataset/mask/mask00028516.png
#   inflating: lips_dataset/mask/mask00028517.png
#   inflating: lips_dataset/mask/mask00028518.png
#   inflating: lips_dataset/mask/mask00028519.png
#   inflating: lips_dataset/mask/mask00028520.png
#   inflating: lips_dataset/mask/mask00028521.png
#   inflating: lips_dataset/mask/mask00028522.png
#   inflating: lips_dataset/mask/mask00028523.png
#   inflating: lips_dataset/mask/mask00028524.png
#   inflating: lips_dataset/mask/mask00028525.png
#   inflating: lips_dataset/mask/mask00028526.png
#   inflating: lips_dataset/mask/mask00028527.png
#   inflating: lips_dataset/mask/mask00028528.png
#   inflating: lips_dataset/mask/mask00028529.png
#   inflating: lips_dataset/mask/mask00028530.png
#   inflating: lips_dataset/mask/mask00028531.png
#   inflating: lips_dataset/mask/mask00028532.png
#   inflating: lips_dataset/mask/mask00028533.png
#   inflating: lips_dataset/mask/mask00028534.png
#   inflating: lips_dataset/mask/mask00028535.png
#   inflating: lips_dataset/mask/mask00028536.png
#   inflating: lips_dataset/mask/mask00028537.png
#   inflating: lips_dataset/mask/mask00028538.png
#   inflating: lips_dataset/mask/mask00028539.png
#   inflating: lips_dataset/mask/mask00028540.png
#   inflating: lips_dataset/mask/mask00028541.png
#   inflating: lips_dataset/mask/mask00028542.png
#   inflating: lips_dataset/mask/mask00028543.png
#   inflating: lips_dataset/mask/mask00028544.png
#   inflating: lips_dataset/mask/mask00028545.png
#   inflating: lips_dataset/mask/mask00028546.png
#   inflating: lips_dataset/mask/mask00028547.png
#   inflating: lips_dataset/mask/mask00028548.png
#   inflating: lips_dataset/mask/mask00028549.png
#   inflating: lips_dataset/mask/mask00028550.png
#   inflating: lips_dataset/mask/mask00028551.png
#   inflating: lips_dataset/mask/mask00028552.png
#   inflating: lips_dataset/mask/mask00028553.png
#   inflating: lips_dataset/mask/mask00028554.png
#   inflating: lips_dataset/mask/mask00028555.png
#   inflating: lips_dataset/mask/mask00028556.png
#   inflating: lips_dataset/mask/mask00028557.png
#   inflating: lips_dataset/mask/mask00028558.png
#   inflating: lips_dataset/mask/mask00028559.png
#   inflating: lips_dataset/mask/mask00028560.png
#   inflating: lips_dataset/mask/mask00028561.png
#   inflating: lips_dataset/mask/mask00028562.png
#   inflating: lips_dataset/mask/mask00028563.png
#   inflating: lips_dataset/mask/mask00028564.png
#   inflating: lips_dataset/mask/mask00028565.png
#   inflating: lips_dataset/mask/mask00028566.png
#   inflating: lips_dataset/mask/mask00028567.png
#   inflating: lips_dataset/mask/mask00028568.png
#   inflating: lips_dataset/mask/mask00028569.png
#   inflating: lips_dataset/mask/mask00028570.png
#   inflating: lips_dataset/mask/mask00028571.png
#   inflating: lips_dataset/mask/mask00028572.png
#   inflating: lips_dataset/mask/mask00028573.png
#   inflating: lips_dataset/mask/mask00028574.png
#   inflating: lips_dataset/mask/mask00028575.png
#   inflating: lips_dataset/mask/mask00028576.png
#   inflating: lips_dataset/mask/mask00028577.png
#   inflating: lips_dataset/mask/mask00028578.png
#   inflating: lips_dataset/mask/mask00028579.png
#   inflating: lips_dataset/mask/mask00028580.png
#   inflating: lips_dataset/mask/mask00028581.png
#   inflating: lips_dataset/mask/mask00028582.png
#   inflating: lips_dataset/mask/mask00028583.png
#   inflating: lips_dataset/mask/mask00028584.png
#   inflating: lips_dataset/mask/mask00028585.png
#   inflating: lips_dataset/mask/mask00028586.png
#   inflating: lips_dataset/mask/mask00028587.png
#   inflating: lips_dataset/mask/mask00028588.png
#   inflating: lips_dataset/mask/mask00028589.png
#   inflating: lips_dataset/mask/mask00028590.png
#   inflating: lips_dataset/mask/mask00028591.png
#   inflating: lips_dataset/mask/mask00028592.png
#   inflating: lips_dataset/mask/mask00028593.png
#   inflating: lips_dataset/mask/mask00028594.png

# %%
DATASET_FILEPATH = Path('/content/lips_dataset')
IMAGES = '720p'
MASKS = 'mask'
LIST_CSV = 'list.csv'

# %%
IMAGES_FILEPATH = DATASET_FILEPATH.joinpath(IMAGES)
MASKS_FILEPATH = DATASET_FILEPATH.joinpath(MASKS)
LIST_CSV_FILEPATH = DATASET_FILEPATH.joinpath(LIST_CSV)

# %%
df_lips_images = pd.read_csv(LIST_CSV_FILEPATH)
df_lips_images.head()
# Out:
#             filename  width  height class  xmin  ymin  xmax  ymax  \
# 0  image00000001.jpg   1280     720  Lips   661   394   776   444
# 1  image00000002.jpg   1280     720  Lips   557   336   682   392
# 2  image00000003.jpg   1280     720  Lips   553   369   684   427
# 3  image00000004.jpg   1280     720  Lips   555   351   681   408
# 4  image00000005.jpg   1280     720  Lips   555   351   680   407
#
#                mask
# 0  mask00000001.png
# 1  mask00000002.png
# 2  mask00000003.png
# 3  mask00000004.png
# 4  mask00000005.png

# %%
feats = ['filename', 'mask']

df_lips_images = df_lips_images[feats]
df_lips_images.head()
# Out:
#             filename              mask
# 0  image00000001.jpg  mask00000001.png
# 1  image00000002.jpg  mask00000002.png
# 2  image00000003.jpg  mask00000003.png
# 3  image00000004.jpg  mask00000004.png
# 4  image00000005.jpg  mask00000005.png

# %%
list_of_an_images = sorted([i for i in Path(IMAGES_FILEPATH).iterdir()])
list_of_a_masks = sorted([i for i in Path(MASKS_FILEPATH).iterdir()])

# %%
len(list_of_an_images), len(list_of_a_masks)
# Out:
# (28594, 28540)

# %%
df_lips_images = df_lips_images.loc[df_lips_images['mask'].isin([i.name for i in list_of_a_masks])]
df_lips_images.reset_index(drop=True, inplace=True)
df_lips_images.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28540 entries, 0 to 28539
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  28540 non-null  object
#  1   mask      28540 non-null  object
# dtypes: object(2)
# memory usage: 446.1+ KB

# %%
IMG_SIZE = 256

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
model = smp.FPN(encoder_name='resnet50',
                encoder_weights='imagenet',
                classes=1,
                activation='sigmoid'
               ).to(device=device)

preprocess_input = smp.encoders.get_preprocessing_fn('resnet50', pretrained='imagenet')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 87.3MB/s]

# %%
def resize_an_image_and_mask(image_filename, mask_filename, new_size):

    image = cv2.imread(str(IMAGES_FILEPATH.joinpath(image_filename)))
    mask = cv2.imread(str(MASKS_FILEPATH.joinpath(mask_filename)))

    resized_image = cv2.cvtColor(cv2.resize(image, (new_size, new_size)), cv2.COLOR_BGR2RGB)
    resized_mask = cv2.cvtColor(cv2.resize(mask, (new_size, new_size)), cv2.COLOR_BGR2RGB)

    return resized_image, resized_mask


class LipsDataset(torch.utils.data.Dataset):

    def __init__(self, data, preprocessing=None):

        self.data = data
        self.preprocessing = preprocessing

        self.images_paths = self.data.iloc[:, 0]
        self.masks_paths = self.data.iloc[:, 1]

        self.data_len = len(self.data.index)

    def __len__(self):
        return self.data_len

    def __getitem__(self, idx):

        img_path = self.images_paths[idx]
        mask_path = self.masks_paths[idx]

        img, mask = resize_an_image_and_mask(img_path, mask_path, IMG_SIZE)

        img = img.astype(float)

        if self.preprocessing:
            img = self.preprocessing(img)
            img = torch.as_tensor(img)
        else:
            img = torch.as_tensor(img)
            img /= 255.0

        img = img.permute(2, 0, 1)

        cls_mask_1 = mask[..., 1]

        cls_mask_1 = np.where(mask > 50, 1, 0)[:,:,1]

        cls_mask_1 = cls_mask_1.astype('float')

        masks = [cls_mask_1]

        masks = torch.as_tensor(masks, dtype=torch.float)


        return img.float(), masks

# %%
X_train, X_valid = train_test_split(df_lips_images, test_size=0.3,random_state=42)

X_train.reset_index(drop=True, inplace=True)
X_valid.reset_index(drop=True, inplace=True)

train_data = LipsDataset(X_train, preprocessing=preprocess_input)
valid_data = LipsDataset(X_valid, preprocessing=preprocess_input)

# %%
train_loader = torch.utils.data.DataLoader(train_data, batch_size=8, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=4, shuffle=False)

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 7))
img_pic = plt.imread(list_of_an_images[0])
img_mask = plt.imread(list_of_a_masks[0])
ax[0].imshow(img_pic)
ax[1].imshow(img_mask)
plt.show()

# %%
for img, target in train_loader:
    print(img.shape, target.shape)
    print(img[0].min(), img[0].max())
    print(target[0].min(), target[0].max())
    fig, ax = plt.subplots(1, 2, figsize=(15, 6))
    ax[0].imshow(img[0].permute(1, 2, 0))
    ax[1].imshow(target[0].permute(1, 2, 0)[...,0])
    break
# Out:
# <ipython-input-15-3ec70a695d0f>:53: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   masks = torch.as_tensor(masks, dtype=torch.float)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([8, 3, 256, 256]) torch.Size([8, 1, 256, 256])
# tensor(-2.0494) tensor(2.6226)
# tensor(0.) tensor(1.)

# %%
criterion = smp.utils.losses.BCELoss()
metrics = [smp.utils.metrics.IoU(), ]
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
train_epoch = smp.utils.train.TrainEpoch(
    model,
    loss=criterion,
    metrics=metrics,
    optimizer=optimizer,
    device=device,
    verbose=True
)

valid_epoch = smp.utils.train.ValidEpoch(
    model,
    loss=criterion,
    metrics=metrics,
    device=device,
    verbose=True
)

# %%
# train model

max_score = 0

for i in range(0, 1):
    print(f'Epoch: {i + 1}')
    train_logs = train_epoch.run(train_loader)
    valid_logs = valid_epoch.run(valid_loader)

    # do something (save model, change lr, etc.)
    if max_score < valid_logs['iou_score']:
        max_score = valid_logs['iou_score']
        torch.save(model, './best_model.pth')
        print('Model saved!')

# %%
net = torch.load('./best_model.pth')

# %%
data_iter = iter(train_loader)

# %%
images, labels = data_iter.next()
images, labels = images.to(device), labels.to(device)

outputs = model(images)

# %%
for i in range(images.shape[0]):

    fig , (ax_1, ax_2, ax_3) = plt.subplots(1, 3, figsize=(16,5))

    image = images[i].permute(1, 2, 0)

    ax_1.imshow(image.cpu())
    ax_1.set_title('Image')

    ax_2.imshow(labels[i, ].cpu().permute(1, 2, 0)[...,0])
    ax_2.set_title('True_mask')

    ax_3.imshow(outputs.detach().cpu()[i, ].permute(1, 2, 0)[...,0])
    ax_3.set_title('Pred_mask')
